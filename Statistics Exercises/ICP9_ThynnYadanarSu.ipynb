# %%
import math
import scipy.stats

ss_total =  52181.73333
ss_between = 10233.06667
ss_within = ss_total - ss_between
print("ss_within =", ss_within)

k = 5
n = 15
ms_factor = ss_between/(k-1)
print("ms_factor =", ms_factor)

ms_error = ss_within/(n-k)
print("ms_error =", ms_error)

f_ratio = ms_factor/ms_error
print("f_ratio =", f_ratio)

print("We will fail to reject the null hypothesis as f-ratio is less than the alpha value 0.05. The null hypothesis is true all the samples are equally significant.")
# Out:
# ss_within = 41948.66666
# ms_factor = 2558.2666675
# ms_error = 4194.866666
# f_ratio = 0.6098564915626808
# We will fail to reject the null hypothesis as f-ratio is <1.

# %%
import math
import scipy.stats


ss_total =  621.4
ss_within = 374.5

ss_between = ss_total - ss_within
print("ss_between =", ss_between)

k = 4
n = 30
ms_factor = ss_between/(k-1)
print("ms_factor =", ms_factor)

ms_error = ss_within/(n-k)
print("ms_error =", ms_error)

f_ratio = ms_factor/ms_error
print("f_ratio =", f_ratio)

print("We will reject the null hypothesis as f-ratio is far greater than the alpha value 0.01. The null hypothesis is false and all the samples have great difference between them.")
# Out:
# ss_between = 246.89999999999998
# ms_factor = 82.3
# ms_error = 14.403846153846153
# f_ratio = 5.713751668891856
# We will fail to reject the null hypothesis as f-ratio is less than the alpha value 0.05. The null hypothesis is true all the samples are equally significant.
